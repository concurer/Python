# %% [markdown]
# Introduction to **Python** **Programming**
#
# File name starting  of python program cannot be a number
# what ever you can do in C,c++,java every thing can be done in Python
#
# code length is less and Rich Files
# Webite development
# swift programming

# %% [markdown]
# Hoe to Create a class in python

# %%
class person:
  def _init_(self,name,age):
    self.name = name
    self.age = age
  def show(self):
    print(self.name+" "+self.age);

p1 = person("Tom",23)
show(p1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-e08baeacb722> in <module>()
#       6     print(self.name+" "+self.age);
#       7
# ----> 8 p1 = Person("Tom",23)
#       9 show(p1)
#
# TypeError: Person() takes no arguments

# %%
#17 jan 2022 First class code
# %%shell
gcc hello.c
#include <stdio.h>
int main()
{
    printf("Hello Python");
    return(0);
}
# Out:
# gcc: error: hello.c: No such file or directory
# gcc: fatal error: no input files
# compilation terminated.
# /bin/bash: -c: line 2: syntax error near unexpected token `('
# /bin/bash: -c: line 2: `int main()'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-6-eded5cb77c65> in <module>()
# ----> 1 get_ipython().run_cell_magic('shell', '', 'gcc hello.c\n#include <stdio.h>\nint main()\n{\n    printf("Hello Python");\n    return(0);\n}\n')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# ...

# %%
print("\U0001f600")
# Out:
# 😀

# %%
print("Hello, World! Welcome to SGGS")
# Out:
# Hello, World! Welcome to SGGS
